# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 4.5

# %%
import ex4_5

# %% [markdown]
# First the original problem, where it costs \$2 to move each car between lots,
# the number of rentals and returns are poisson distributed with expected numbers 3 and 3
# for *lot 1* and 4 and 2 for *lot 2*, and each rental generates $10 of revenue.

# %%
ex4_5.visualize("./ex4_5_original_problem_model.cpkl")
# Out:
# Attempting to load model...
# Loaded.

# %% [markdown]
# Now the second problem, in which an employee can take one car from lot 1 to lot 2 per night for free, and in which a $4 fee will be charged per location if > 10 cars are stored at that location overnight.

# %%
ex4_5.visualize("./ex4_5_second_problem_model.cpkl")
# Out:
# Attempting to load model...
# Loaded.
